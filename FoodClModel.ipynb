# %%
# !pip install kaggle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.17-py3-none-any.whl size=105786 sha256=176a0c95473e2e240a8d4e9b9e091b75196e882e0cb1428fc79d07631365c36a
#   Stored in directory: /Users/kartikeysharma/Library/Caches/pip/wheels/ff/55/fb/b27a466be754d2a06ffe0e37b248d844f090a63b51becea85d
# Successfully built kaggle
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d harishkumardatalab/food-image-classification-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/harishkumardatalab/food-image-classification-dataset
# License(s): CC0-1.0
# ...
# 100%|█████████████████████████████████████▉| 1.68G/1.68G [02:17<00:00, 14.1MB/s]
# 100%|██████████████████████████████████████| 1.68G/1.68G [02:17<00:00, 13.2MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/food-image-classification-dataset.zip', 'r')
zip_ref.extractall('/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model')
zip_ref.close()

# %%
from PIL import Image
import os

# Path to your dataset
dataset_path = '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/Food Classification dataset'

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.endswith('.jpg') or file.endswith('.png'):
            try:
                img = Image.open(os.path.join(root, file))
                img.verify()  # Verify image integrity
                print(f"{file} is good")
            except (IOError, SyntaxError) as e:
                print(f"{file} is corrupted")
# Out:
# 189.jpg is good
# 162.jpg is good
# 176.jpg is good
# download (1).jpg is good
# images (1).jpg is good
# 228.jpg is good
# 200.jpg is good
# images (13).jpg is good
# 016.jpg is good
# 002.jpg is good
# 003.jpg is good
# 017.jpg is good
# 201.jpg is good
# 215.jpg is good
# 229.jpg is good
# 163.jpg is good
# 188.jpg is good
# 149.jpg is good
# 175.jpg is good
# 161.jpg is good
# 203.jpg is good
# 217.jpg is good
# 029.jpg is good
# 001.jpg is good
# 015.jpg is good
# 216.jpg is good
# 202.jpg is good
# 160.jpg is good
# 174.jpg is good
# 148.jpg is good
# 170.jpg is good
# 164.jpg is good
# 158.jpg is good
# 212.jpg is good
# download.jpg is good
# 004.jpg is good
# 010.jpg is good
# 038.jpg is good
# 039.jpg is good
# 011.jpg is good
# 005.jpg is good
# 213.jpg is good
# 207.jpg is good
# 171.jpg is good
# 198.jpg is good
# 167.jpg is good
# 173.jpg is good
# 205.jpg is good
# 239.jpg is good
# 013.jpg is good
# 007.jpg is good
# images (12).jpg is good
# 006.jpg is good
# ...

# %%
import os
import re

# Path to the dataset
dataset_path = '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/Food Classification dataset'

# Loop through all files in the dataset directory
for root, dirs, files in os.walk(dataset_path):
    for file in files:
        file_path = os.path.join(root, file)

        # Check if the filename is numeric (without extension)
        file_name, file_ext = os.path.splitext(file)

        if file_name.isnumeric():
            # If the name is already numeric, keep it as is
            print(f'Already Numeric: {file}')
            continue

        # Check if the name has a number in parentheses, e.g., "image(123).jpg"
        match = re.search(r'\((\d+)\)', file_name)

        if match:
            # Extract the number and rename the file
            new_file_name = match.group(1) + file_ext
            new_file_path = os.path.join(root, new_file_name)
            os.rename(file_path, new_file_path)
            print(f'Renamed: {file} -> {new_file_name}')
        else:
            # If the name doesn't fit, remove the file
            os.remove(file_path)
            print(f'Removed: {file}')
# Out:
# Already Numeric: 189.jpg
# Already Numeric: 162.jpg
# Already Numeric: 176.jpg
# Renamed: download (1).jpg -> 1.jpg
# Renamed: images (1).jpg -> 1.jpg
# Already Numeric: 228.jpg
# Already Numeric: 200.jpg
# Renamed: images (13).jpg -> 13.jpg
# Already Numeric: 016.jpg
# Already Numeric: 002.jpg
# Already Numeric: 003.jpg
# Already Numeric: 017.jpg
# Already Numeric: 201.jpg
# Already Numeric: 215.jpg
# Already Numeric: 229.jpg
# Already Numeric: 163.jpg
# Already Numeric: 188.jpg
# Already Numeric: 149.jpg
# Already Numeric: 175.jpg
# Already Numeric: 161.jpg
# Already Numeric: 203.jpg
# Already Numeric: 217.jpg
# Already Numeric: 029.jpg
# Already Numeric: 001.jpg
# Already Numeric: 015.jpg
# Already Numeric: 014.JPG
# Already Numeric: 028.JPG
# Already Numeric: 216.jpg
# Already Numeric: 202.jpg
# Already Numeric: 160.jpg
# Already Numeric: 174.jpg
# Already Numeric: 148.jpg
# Already Numeric: 170.jpg
# Already Numeric: 164.jpg
# Already Numeric: 158.jpg
# Already Numeric: 212.jpg
# ...

# %%
from PIL import Image
import os

# Path to your dataset
dataset_path = '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/Food Classification dataset'

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        if file.endswith('.jpg') or file.endswith('.png'):
            try:
                img = Image.open(os.path.join(root, file))
                img.verify()  # Verify image integrity
                print(f"{file} is good")
            except (IOError, SyntaxError) as e:
                print(f"{file} is corrupted")
# Out:
# 189.jpg is good
# 162.jpg is good
# 176.jpg is good
# 228.jpg is good
# 200.jpg is good
# 016.jpg is good
# 002.jpg is good
# 003.jpg is good
# 017.jpg is good
# 201.jpg is good
# 215.jpg is good
# 229.jpg is good
# 163.jpg is good
# 188.jpg is good
# 149.jpg is good
# 175.jpg is good
# 161.jpg is good
# 203.jpg is good
# 217.jpg is good
# 029.jpg is good
# 001.jpg is good
# 015.jpg is good
# 216.jpg is good
# 202.jpg is good
# 160.jpg is good
# 174.jpg is good
# 148.jpg is good
# 170.jpg is good
# 164.jpg is good
# 158.jpg is good
# 212.jpg is good
# 004.jpg is good
# 010.jpg is good
# 038.jpg is good
# 039.jpg is good
# 011.jpg is good
# 005.jpg is good
# 213.jpg is good
# 207.jpg is good
# 171.jpg is good
# 8.jpg is good
# 198.jpg is good
# 167.jpg is good
# 173.jpg is good
# 205.jpg is good
# 239.jpg is good
# 013.jpg is good
# 007.jpg is good
# 006.jpg is good
# 012.jpg is good
# 204.jpg is good
# 210.jpg is good
# 172.jpg is good
# 166.jpg is good
# 199.jpg is good
# ...

# %%
import os
import shutil
import random

# Define the path to your dataset
data_dir = '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/Food Classification dataset'

# Define the path to your training and testing directories
train_dir = '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/train'
test_dir = '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/test'

# Create the training and testing directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Define the split ratio (e.g., 80% for training, 20% for testing)
split_ratio = 0.8

# Iterate over each food category
for category in os.listdir(data_dir):
  category_path = os.path.join(data_dir, category)
  if os.path.isdir(category_path):
    # Create subdirectories for the category in training and testing directories
    train_category_path = os.path.join(train_dir, category)
    test_category_path = os.path.join(test_dir, category)
    os.makedirs(train_category_path, exist_ok=True)
    os.makedirs(test_category_path, exist_ok=True)

    # Get the list of images in the category
    images = os.listdir(category_path)

    # Shuffle the images randomly
    random.shuffle(images)

    # Calculate the split index
    split_index = int(len(images) * split_ratio)

    # Split the images into training and testing sets
    train_images = images[:split_index]
    test_images = images[split_index:]

    # Move the images to their respective directories
    for image in train_images:
      src_path = os.path.join(category_path, image)
      dest_path = os.path.join(train_category_path, image)
      shutil.move(src_path, dest_path)

    for image in test_images:
      src_path = os.path.join(category_path, image)
      dest_path = os.path.join(test_category_path, image)
      shutil.move(src_path, dest_path)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create a data generator for training and validation
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)  # Normalize pixel values and split for validation

# Define training and validation generators
train_generator = train_datagen.flow_from_directory(
    '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/train',  # The path where images are stored
    target_size=(150, 150),  # Resize images to (150, 150)
    batch_size=32,
    class_mode='categorical',  # Multi-class classification
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    '/Users/kartikeysharma/Desktop/Hanuman/Projects/Food Classification & Detection + Calorie Counter/New Model/test',
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 15149 images belonging to 34 classes.
# Found 939 images belonging to 34 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Build the CNN model
model = models.Sequential()

# Add convolutional and pooling layers
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Flatten and fully connected layers
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(34, activation='softmax'))  # 34 classes

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# Epoch 1/10
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 389/473 ━━━━━━━━━━━━━━━━━━━━ 25s 302ms/step - accuracy: 0.0953 - loss: 3.2127
# /opt/anaconda3/lib/python3.11/site-packages/PIL/Image.py:981: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 152s 319ms/step - accuracy: 0.1045 - loss: 3.1707 - val_accuracy: 0.2155 - val_loss: 2.6085
# Epoch 2/10
# 473/473 ━━━━━━━━━━━━━━━━━━━━ 0s 108us/step - accuracy: 0.2500 - loss: 2.3164 - val_accuracy: 0.3636 - val_loss: 2.2024
# Epoch 3/10
# ...

# %%
# Evaluate the model
loss, accuracy = model.evaluate(validation_generator)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - accuracy: 0.3701 - loss: 3.0766
# Validation Accuracy: 35.68%

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.save('food_classification_model1.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('food_classification_model1.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# ------------------ Ek Function -------------------------- #

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# Load and preprocess the image
def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))  # Resize to 150x150
    img_array = image.img_to_array(img)  # Convert image to array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = img_array / 255.0  # Normalize pixel values to 0-1
    return img_array

# Path to the image you want to test
img_path = '/Users/kartikeysharma/Downloads/fries.jpeg'
preprocessed_image = preprocess_image(img_path)

# %%
# Predict the class of the image
prediction = model.predict(preprocessed_image)

# Get the predicted class index
predicted_class = np.argmax(prediction, axis=1)
print(f'Predicted Class: {predicted_class[0]}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Predicted Class: 3

# %%
# Assuming you have a class mapping from index to label
class_indices = train_generator.class_indices
index_to_class = {v: k for k, v in class_indices.items()}  # Reverse the dictionary

# Print the predicted class name
predicted_class_name = index_to_class[predicted_class[0]]
print(f'Predicted Class Name: {predicted_class_name}')
# Out:
# Predicted Class Name: Fries

# %%
import pandas as pd

# %%
cal_data = pd.read_csv("/Users/kartikeysharma/Downloads/Food and Their Calorie(Sheet1).csv")

# %%
cal_data
# Out:
#     Food Item Name                                            Calorie
# 0     Baked Potato                  ~160 kcal (1 medium-sized potato)
# 1   Crispy Chicken            ~400-500 kcal (1 medium serving, fried)
# 2           Donut                      ~250-300 kcal (1 glazed donut)
# 3           Fries                 ~365 kcal (1 medium serving, ~117g)
# 4         Hot Dog        ~150-200 kcal (with bun, without condiments)
# 5         Sandwich       ~250-400 kcal (depends on fillings and size)
# 6             Taco       ~150-300 kcal (1 taco, depending on filling)
# 7          Taquito                  ~200 kcal (1 small fried taquito)
# 8        apple_pie                         ~320 kcal (1 slice, ~100g)
# 9           burger  ~300-600 kcal (depending on patty size and top...
# 10     butter_naan                           ~200 kcal (1 naan, ~75g)
# 11            chai         ~120-150 kcal (1 cup, with milk and sugar)
# ...

# %%
print(cal_data.iloc[predicted_class]['Food Item Name'])
print(cal_data.iloc[predicted_class]['Calorie'])
# Out:
# 3    Fries
# Name: Food Item Name, dtype: object
# 3    ~365 kcal (1 medium serving, ~117g)
# Name: Calorie, dtype: object

# %%
r1= cal_data['Food Item Name'].iloc[predicted_class].item()
r1
# Out:
# 'Fries '

# %%
r=cal_data.iloc[predicted_class]['Calorie']
r.item()
# Out:
# '~365 kcal (1 medium serving, ~117g)'
